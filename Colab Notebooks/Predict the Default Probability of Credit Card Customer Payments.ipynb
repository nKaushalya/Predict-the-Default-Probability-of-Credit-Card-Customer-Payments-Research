# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Loading the sample dataset
credit_card = pd.read_csv('/content/drive/My Drive/w1790011_FYP_6COSC023W.Y2023/Data Set/credit_card_default_payments_cleaned_data_set.csv')
print(credit_card.columns)
# Out:
# Index(['Unnamed: 0', 'Product Age in Months', 'Age', 'Product', 'Gender',
#        'Limit', 'Gross Income', 'DPD Group', 'Credit Segment',
#        'Settler and Revolver', 'Retail Segment', 'Employment Status',
#        'Nature of Business', 'Application Score', 'Total OS Month N',
#        'Spend Month N', 'Spend Month N-1', 'Spend Month N-2',
#        'Payment Month N', 'Payment Month N-1', 'Payment Month N-2',
#        'Int Month N', 'Int Month N-1', 'Int Month N-2', 'Method Month N',
#        'Method Month N-1', 'Method Month N-2', 'Payment Default in Month N+1'],
#       dtype='object')

# %%
#Load the Model File
import pickle
model_x = pickle.load(open('/content/drive/My Drive/w1790011_FYP_6COSC023W.Y2023/Prediction Model/credit_card_finalized_model.sav', 'rb'))

# %%
#Predict the Default Probability of Credit Card Customer Payments - Single Input
predictionProbability = model_x.predict_proba([[]])
prediction = model_x.predict([[12,13,]])
print('Probability:', predictionProbability)
print('Probability %:', predictionProbability*100)
print('Prediction:', prediction)

# %%
#Predict the Default Probability of Credit Card Customer Payments - Sample Inputs
sampleData = credit_card[:10]
sampleDataFeatures = np.asarray(sampleData.drop(['Payment Default in Month N+1', 'Unnamed: 0', 'Nature of Business','Credit Segment','Method Month N-1','Method Month N','Application Score','Product','Method Month N-2','Employment Status','Gender','Retail Segment'], axis=1))
print(sampleDataFeatures)

predictionProbability = model_x.predict_proba(sampleDataFeatures)
prediction = model_x.predict(sampleDataFeatures)
print('Probability:', predictionProbability)
print('Probability %:', predictionProbability*100)
print('Prediction:', prediction)
# Out:
# [[1.3900000e+02 6.2000000e+01 2.2500000e+06 5.9000000e+07 2.0000000e+00
#   2.0000000e+00 1.2771300e+06 6.3541500e+05 1.2931040e+06 0.0000000e+00
#   0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00
#   3.8960000e+03]
#  [1.2600000e+02 4.0000000e+01 2.7000000e+06 1.2097419e+07 1.0000000e+00
#   1.0000000e+00 2.8969790e+06 0.0000000e+00 0.0000000e+00 0.0000000e+00
#   9.7600000e+04 9.7100000e+04 1.5900000e+05 0.0000000e+00 0.0000000e+00
#   0.0000000e+00]
#  [1.7400000e+02 3.6000000e+01 1.2600000e+06 1.9953800e+06 1.0000000e+00
#   1.0000000e+00 1.2563870e+06 3.8848500e+05 4.1721900e+05 0.0000000e+00
#   1.6950000e+05 0.0000000e+00 1.1000000e+05 0.0000000e+00 0.0000000e+00
#   0.0000000e+00]
